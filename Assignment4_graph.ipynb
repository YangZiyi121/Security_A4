# %% [markdown]
# **Question 5**
#
# **a)**

# %%
import numpy as np
study = np.loadtxt('study.400')
study_byte0_aver = study[52480:52736,6]

# %%
import matplotlib.pyplot as plt
x = np.arange(256)
plt.plot(x, study_byte0_aver, '.')
plt.axhline(y=0, c="r", ls="--", lw=2)
plt.show()

# %% [markdown]
# **b)**

# %%
import numpy as np
attack = np.loadtxt('attack.400')
attack_byte0_aver = attack[52480:52736,6]

# %%
import matplotlib.pyplot as plt
x = np.arange(256)
plt.plot(x, attack_byte0_aver, '.')
plt.axhline(y=0, c="r", ls="--", lw=2)
plt.show()
